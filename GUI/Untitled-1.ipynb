# %%
import pandas as pd
data =pd.read_csv("application_train.csv",encoding='cp1252',header=0)

# %%
data=data.head(20)

# %%
columns=list(data.columns)

# %%
X,Y=data.shape

# %%
for row in range(X):
    for col in range(Y):
        print(row,col,data.iloc[row][col])
# Out:
# 0 0 100002
# 0 1 1
# 0 2 Cash loans
# 0 3 M
# 0 4 N
# 0 5 Y
# 0 6 0
# 0 7 202500.0
# 0 8 406597.5
# 0 9 24700.5
# 0 10 351000.0
# 0 11 Unaccompanied
# 0 12 Working
# 0 13 Secondary / secondary special
# 0 14 Single / not married
# 0 15 House / apartment
# 0 16 0.018801
# 0 17 -9461
# 0 18 -637
# 0 19 -3648.0
# 0 20 -2120
# 0 21 nan
# 0 22 1
# 0 23 1
# 0 24 0
# 0 25 1
# 0 26 1
# 0 27 0
# 0 28 Laborers
# 0 29 1.0
# 0 30 2
# 0 31 2
# 0 32 WEDNESDAY
# 0 33 10
# 0 34 0
# 0 35 0
# 0 36 0
# 0 37 0
# 0 38 0
# 0 39 0
# 0 40 Business Entity Type 3
# 0 41 0.0830369673913225
# 0 42 0.2629485927471776
# 0 43 0.1393757800997895
# 0 44 0.0247
# 0 45 0.0369
# 0 46 0.9722
# 0 47 0.6192
# 0 48 0.0143
# 0 49 0.0
# 0 50 0.069
# 0 51 0.0833
# 0 52 0.125
# 0 53 0.0369
# 0 54 0.0202
# 0 55 0.019
# 0 56 0.0
# 0 57 0.0
# 0 58 0.0252
# 0 59 0.0383
# 0 60 0.9722
# 0 61 0.6341
# 0 62 0.0144
# 0 63 0.0
# 0 64 0.069
# 0 65 0.0833
# 0 66 0.125
# 0 67 0.0377
# 0 68 0.022
# 0 69 0.0198
# 0 70 0.0
# 0 71 0.0
# ...
